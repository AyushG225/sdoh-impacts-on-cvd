# %%
import pandas as pd
import math
import numpy as np

# %%
df = pd.read_csv('Combined_AHRQ_Data.csv')

# %%
df = df[df.columns[1:]]

# %%
corr_matrix = df.corr()
# Out:
# C:\Users\anush\AppData\Local\Temp\ipykernel_14516\3147368345.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
corr_matrix
# Out:
#                                 YEAR    COUNTYFIPS     STATEFIPS  \
# YEAR                    1.000000e+00  5.026856e-14  4.858529e-14
# COUNTYFIPS              5.026856e-14  1.000000e+00  9.999789e-01
# STATEFIPS               4.858529e-14  9.999789e-01  1.000000e+00
# TERRITORY               1.963890e-14  3.987929e-01  3.994457e-01
# ACS_TOT_POP_WT          6.876456e-03 -6.635024e-02 -6.610129e-02
# ...                              ...           ...           ...
# MMD_BIPOLAR_DISD                 NaN -7.559132e-02 -7.592908e-02
# MMD_DEPR_DISD                    NaN -5.930341e-02 -5.959569e-02
# MMD_PERSONALITY_DISD             NaN -1.424453e-01 -1.421686e-01
# MMD_OUD_IND                      NaN -1.138529e-01 -1.137289e-01
# MMD_THREE_OR_MORE_COND           NaN -2.605867e-02 -2.721585e-02
#
#                            TERRITORY  ACS_TOT_POP_WT  ACS_TOT_POP_US_ABOVE1  \
# YEAR                    1.963890e-14        0.006876               0.007313
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
corr_matrix.to_csv('Correlation_Matrix_AHRQ.csv')

# %%
df[df['ACS_PCT_INC50'].isna()]['COUNTY']
# Out:
# 3129      American Samoa
# 3130                Guam
# 3131     Mariana Islands
# 6339      American Samoa
# 6340                Guam
# 6341     Mariana Islands
# 9549      American Samoa
# 9550                Guam
# 9551     Mariana Islands
# 12759     American Samoa
# 12760               Guam
# 12761    Mariana Islands
# 15969     American Samoa
# 15970               Guam
# 15971    Mariana Islands
# 19179     American Samoa
# 19180               Guam
# 19181    Mariana Islands
# 22389     American Samoa
# 22390               Guam
# 22391    Mariana Islands
# 25599     American Samoa
# 25600               Guam
# 25601    Mariana Islands
# 28809     American Samoa
# 28810               Guam
# 28811    Mariana Islands
# 32019     American Samoa
# 32020               Guam
# 32021    Mariana Islands
# Name: COUNTY, dtype: object

# %%
df['ACS_PCT_INC50'].isna().sum()
# Out:
# 30

# %%
variables = "CAF_ADJ_COUNTY_12	CAF_ADJ_COUNTY_13	CHR_AVG_LIFE_EXPEC	CAF_ADJ_COUNTY_11	PIAAC_LIT_PCT_LEVEL3_OR_ABOVE	PIAAC_NUM_PCT_LEVEL3_OR_ABOVE	ACS_PCT_BACHELOR_DGR	PIAAC_NUM_AVG_SCORE	ACS_PCT_POSTHS_ED	SAIPE_MEDIAN_HH_INCOME	PIAAC_LIT_AVG_SCORE	CHR_PCT_EXCESS_DRINK	SEDA_MATH_GR8_WNG	SEDA_CS_MN_MATH_GR8_WHT	SEDA_CS_MN_MATH_GR8_ALL	SEDA_MATH_GR3_WNG	SEDA_ELA_GR3_WNG	SEDA_ELA_GR8_WNG	SEDA_CS_MN_ELA_GR8_WHT	ACS_MEDIAN_HOME_VALUE	SEDA_CS_MN_ELA_GR8_ALL	ACS_PCT_VET_BACHELOR	ACS_PER_CAPITA_INC	SEDA_CS_MN_MATH_GR8_MTR	ACS_MEDIAN_HH_INC	ACS_PCT_HH_PC	ACS_MDN_OWNER_COST_MORTGAGE	SEDA_CS_MN_MATH_GR8_NEC	ACS_MEDIAN_HH_INC_WHITE	ACS_MEDIAN_NONVET_INC	SEDA_CS_MN_ELA_GR8_MTR	ACS_PCT_HH_INC_100000	ACS_PCT_HEALTH_INC_ABOVE400	ACS_PCT_HH_INTERNET	SEDA_MATH_GR3_WHG	ACS_PCT_HH_BROADBAND	ACS_MEDIAN_INC_F	ACS_PCT_HH_BROADBAND_ANY	SEDA_CS_MN_ELA_GR8_BLK	ACS_PCT_GRADUATE_DGR	SEDA_MATH_GR8_WHG	SEDA_CS_MN_MATH_GR3_WHT	ACS_PCT_PRIVATE_ANY_BELOW64	SEDA_CS_MN_MATH_GR3_ALL	SEDA_CS_MN_ELA_GR3_MTR	ACS_PCT_PRIVATE_ANY	NEPHTN_PCT_PARK	ACS_PCT_PRIVATE_SELF	ACS_MEDIAN_INC_M	SEDA_CS_MN_MATH_GR3_MTR	CRE_RATE_RISK0	ACS_MEDIAN_RENT	ACS_PCT_PRIVATE_SELF_BELOW64	SEDA_CS_MN_ELA_GR3_WHT	LTC_AVG_AGE	ACS_PCT_CTZ_NONUS_BORN	SEDA_CS_MN_MATH_GR8_ECD	SEDA_MATH_GR8_WBG	ACS_PCT_PERSON_INC_ABOVE200	CAF_ADJ_COUNTY_10	SEDA_CS_MN_ELA_GR3_ALL	ACS_MEDIAN_VET_INC	ACS_PCT_CTZ_NATURALIZED	ACS_MDN_OWNER_COST_NO_MORTG	SEDA_CS_MN_ELA_GR8_NEC	OPP_TOP20_WHT_F_HH_1PT	OPP_TOP20_WHT_F_HH_25PT	CCBP_FSR_RATE	ACS_PCT_ENGL_WELL	SEDA_CS_MN_MATH_GR8_BLK	CCD_LOCAL_REVENUE_LUNCH	ACS_PCT_FOREIGN_BORN	SEDA_CS_MN_ELA_GR3_BLK	CCBP_FCRSC_RATE	ACS_PCT_10UNITS	ACS_MDN_GRNDPRNT_INC	ACS_PCT_PROFESS	ACS_MEDIAN_HH_INC_BLACK	LTC_AVG_PCT_PVT_PATIENT_DAYS	SEDA_MATH_GR3_WBG	OPP_TOP20_WHT_M_HH_25PT	ACS_PCT_HH_TABLET	OPP_TOP20_WHT_M_HH_1PT	ACS_PCT_ENGL_NOT_WELL	ACS_PCT_HISPANIC	ACS_PCT_COLLEGE_ASSOCIATE_DGR	ACS_PCT_ENGL_VERY_WELL	ACS_PCT_SPANISH	SEDA_CS_MN_MATH_GR3_NEC	OPP_TOP20_WHT_F_HH_50PT	SEDA_ELA_GR8_WHG	ACS_PCT_PRIVATE_EMPL_BELOW64	SEDA_ELA_GR3_WHG	CRDC_PCT_APEXAM_ONEORMORE	SEDA_CS_MN_ELA_GR8_ECD	OPP_TOP20_BLK_F_HH_25PT	AHRF_PHYS_PRIMARY_RATE	ACS_PCT_HH_LIMIT_ENGLISH	SEDA_CS_MN_MATH_GR3_BLK	ACS_PCT_VET_LABOR_FORCE_18_64	AHRF_DENTISTS_RATE	ACS_PCT_WHITE_COMB	ACS_PCT_PRIVATE_EMPL	OPP_TOP20_WHT_M_HH_50PT	MP_PCT_ADVTG_PEN	MGV_PER_CAPITA_ACTUAL_OP	ACS_PCT_WALK_2WORK	ACS_PCT_FINANCE	ACS_PCT_HH_INC_99999	AHRF_MDS_RATE	ACS_PCT_PVT_NONPROFIT	ACS_PCT_NON_CITIZEN	ACS_PCT_HOUSEHOLDER_WHITE	ACS_PCT_HH_CELLULAR	ACS_PCT_ASIAN_COMB	CHR_SEGREG_BLACK	ACS_PCT_NONCTN_2010	AHRF_OTHER_SPEC_RATE	ACS_PCT_ASIAN	ACS_PCT_HU_NO_FUEL	ACS_PCT_ENGL_NOT_ALL	ACS_PCT_WHITE	ACS_PCT_ASIAN_NONHISP	ACS_PCT_GRANDP_NO_RESPS	AHRF_ER_MED_RATE	ACS_PCT_EMPLOYED	ACS_MDN_GRNDPRNT_NO_PRNT_INC	AHRF_MARKET_ENROL_400	AHRF_MARKET_ENROL_NO_ASST	ACS_PCT_NONCTN_2000	OPP_TOP20_BLK_F_HH_1PT	OPP_TOP20_BLK_M_HH_25PT	ACS_PCT_API_LANG	ACS_PCT_HOUSEHOLDER_ASIAN	CRDC_PCT_LEP_STUDENTS	CCD_TOT_LOCAL_REVENUE	ACS_PCT_HU_SOLAR	TERRITORY	ACS_MEDIAN_HH_INC_MULTI	ACS_PCT_HH_SMARTPHONE	AHRF_REC_USDA	SEDA_ELA_GR3_WBG	OPP_TOP20_BLK_F_HH_50PT	AHRF_PSYCH_RATE	SEDA_CS_MN_ELA_GR3_NEC	CCD_TOT_REVENUE	AHRF_MARKET_ENROL_300	SEDA_ELA_GR8_WBG	SEDA_CS_MN_MATH_GR3_ECD	FEA_TOT_FARMERS_MARKET	CCD_TOT_EXPENDITURE	ACS_PCT_MARRIED_SP_PR_F	SEDA_CS_TOT_ELA_GR8_MTR	AHRF_ANESTH_RATE	ACS_PCT_INFORM	LTC_AVG_OBS_SUCCESSFUL_DISC_RATE	CRDC_TOT_STUD_WHT_M	CRDC_TOT_STUD_WHT_F	OPP_TOP20_OTHER_F_HH_25PT	SEDA_CS_TOT_ELA_GR3_MTR	AHRF_PHYSICIAN_ASSIST_RATE	SEDA_CS_MN_ELA_GR8_ASN	SEDA_CS_TOT_MATH_GR3_MTR	ACS_PCT_ART	SEDA_CS_TOT_ELA_GR3_NEC	AHRF_ORTH_SURG_RATE	SEDA_CS_TOT_ELA_GR8_NEC	ACS_PCT_HOUSEHOLDER_OTHER	SEDA_CS_TOT_ELA_GR3_WHT	SEDA_CS_TOT_ELA_GR8_WHT	OPP_TOP20_BLK_M_HH_1PT	ACS_PCT_NONCTN_1999	OPP_TOP20_WHT_F_N	SEDA_CS_TOT_MATH_GR3_WHT	ACS_PCT_OTH_EURP	SEDA_CS_TOT_MATH_GR8_MTR	ACS_PCT_HU_OTHER	ACS_PCT_OTHER_RACE	OPP_TOP20_WHT_M_N	AHRF_MARKET_ENROL_OTHER	AHRF_PEDIATRICS_RATE	OPP_INCAR_WHT_F_N	AHRF_MARKET_ENROL_250	OPP_INCAR_WHT_M_N	ACS_PCT_DIF_STATE	CCBP_SFS_RATE	LTC_PCT_RESD_WHITE	AHRF_MED_SPEC_RATE	SEDA_CS_TOT_MATH_GR3_NEC	SEDA_CS_TOT_MATH_GR8_WHT	CRE_TOT_RISK0	CAF_ADJ_COUNTY_7	OPP_TOP20_BLK_M_HH_50PT	MGV_PCT_BEN_FFS_HISPANIC	CCBP_RET_RATE	CAF_ADJ_COUNTY_1	ACS_PCT_NONCTN_1990	OPP_TOP20_OTHER_F_HH_1PT	AHRF_GEN_INTERNAL_MED_RATE	OPP_INCAR_NAM_M_HH_25PT	CDCAP_HIVDIAG_ASN_RATE_ABOVE13	AHRF_SURG_SPECS_RATE	CRDC_TOT_STUD_MTR_F	SEDA_CS_MN_ELA_GR8_HSP	SEDA_CS_TOT_MATH_GR8_NEC	AHRF_PLASTIC_SURG_RATE	AHRF_OPHTHALMOLOGY_RATE	CAF_ADJ_COUNTY_6	CRDC_TOT_STUD_MTR_M	MGV_PER_CAPITA_STD_OP	AHRF_DERMATOLOGY_RATE	CAF_ADJ_COUNTY_2	CRDC_TOT_LEA	CAF_ADJ_COUNTY_3	OPP_INCAR_BLK_M_HH_25PT	CHR_MENTAL_PROV_RATE	AHRF_OB_GYN_RATE	SEDA_MATH_GR8_NEG	NOAAS_TOT_STORMEVENT	OPP_TOP20_OTHER_F_N	OPP_TOP20_OTHER_F_HH_50PT	CDC_USCS_TOT_INC_COUNT	YEAR	ACS_PCT_WORK_RES_M	ACS_PCT_SELF_MDCR_ABOVE35	POS_MAX_DIST_CLINIC	AHRF_VET_MALE	AHRF_VET	ACS_PCT_HH_BROADBAND_ONLY	SEDA_CS_TOT_ELA_GR3_ASN	AHRF_GASTROENTEROLOGY_RATE	OPP_TOP20_OTHER_M_N	CRDC_TOT_FTECOUNSELORS	CRDC_TOT_PRESCHOOL_WHT_M	SEDA_CS_TOT_MATH_GR3_ASN	CAF_ADJ_COUNTY_4	CRDC_PCT_COUNTY_ECE	AHRF_TOT_PHYS_PRIMARY	AHRF_TOT_NURSE_MIDWIVES	AHRF_CHLD_PSYCH_RATE	CAF_ADJ_COUNTY_5	STATEFIPS	CRDC_TOT_SCHOOLS	ACS_PCT_HU_OIL	SEDA_CS_MN_MATH_GR3_ASN	COUNTYFIPS	AHRF_ALLERGY_IMM_RATE	CRDC_TOT_FTETEACH_ABSENT	CRDC_TOT_SPEDS	CHR_TOT_MENTAL_PROV	POS_TOT_HOSP_CHEMO	LTC_PCT_RESD_HISPANIC	AHRF_MARKET_ENROL_200	AHRF_TOT_ER_MED	SEDA_CS_MN_ELA_GR3_ECD	CRDC_TOT_FTETEACH_CERT	SEDA_CS_TOT_ELA_GR8_ASN	AHRF_MARKET_ENROL_AUTO	AHRF_VET_FEMALE	AHRF_MARKET_ENROL_ACTIVE	MGV_TOT_BEN_PART_A_B	CRE_TOT_POP_DENOM	SEDA_CS_TOT_MATH_GR8_ASN	PIAAC_POP_TARGET	CHR_TOT_POPULATION	ACS_PCT_MARRIED_SP_PR_M	OPP_INCAR_OTHER_F_N	AMFAR_TOT_MHFAC	NHC_TOT_FACS	SEDA_CS_MN_ELA_GR3_ASN	ACS_PCT_WORK_RES_F	AHRF_RADI_RATE	SEDA_CS_MN_MATH_GR8_ASN	AHRF_TOT_PHYSICIAN_ASSIST	OPP_TOP20_HSP_F_HH_25PT	ACS_TOT_CIVIL_VET_POP_ABOVE25	ACS_TOT_CIVIL_VET_POP	MGV_TOT_BEN_FFS	AHRF_MARKET_ENROL	ACS_PCT_PUBL_TRANSIT	SEDA_MATH_GR8_WAG	SEDA_MATH_GR3_NEG	AHRF_TOT_ORTH_SURG	CRDC_TOT_STUDENTS	POS_HOSP_OBSTETRIC_RATE	AHRF_TOT_CHLD_PSYCH	AMFAR_TOT_MEDMHFAC	CRDC_TOT_STUD_IDEA	AHRF_TOT_DENTISTS	AHRF_TOT_MDS	NEPHTN_ARSENIC_MEAN_CSW	AHRF_TOT_PEDIATRICS	CDC_USCS_TOT_MORT_COUNT	AHRF_TOT_OTHER_SPEC	CRDC_TOT_ALT	CRE_TOT_RISK12	POS_TOT_HOSP_OBSTETRIC	CCBP_ANNUAL_TOT_POP	AHRF_TOT_DERMATOLOGY	OPP_INCAR_BLK_M_HH_1PT	AHRF_TOT_GEN_PREV	MP_MEDICARE_ADVTG_ENROLLED	ACS_TOT_WORKER_HH	ACS_TOT_CIVIL_EMPLOY_POP	ACS_TOT_POP_US_ABOVE1	CDCW_TOT_POPULATION	AHRF_TOT_ANESTH	OPP_TOP20_WHT_M_HH_75PT	SEDA_CS_TOT_ELA_GR3_ALL	ACS_TOT_WORKER_NWFH	OPP_TOP20_ASN_F_N	SEDA_CS_TOT_ELA_GR8_ALL	SAHIE_TOT_POP64	OPP_INCAR_OTHER_M_N	AHRF_TOT_GASTROENTEROLOGY	OPP_INCAR_NAM_M_HH_1PT	CRDC_TOT_PRESCHOOL_WHT_F	AHRF_TOT_ALLERGY_IMM	MP_MEDICARE_ELIGIBLES	POS_MEAN_DIST_CLINIC	ACS_TOT_CIVILIAN_LABOR	ACS_TOT_CIVIL_POP_POV	CRDC_TOT_PRESCHOOL_ASN_M	POS_MEDIAN_DIST_CLINIC	OPP_INCAR_NAM_M_HH_50PT	CCBP_CHILD_RATE	ACS_TOT_CIVIL_NONINST_POP	AHRF_NURSE_MIDWIVES_RATE	OPP_TOP20_ASN_M_N	ACS_TOT_CIVIL_NONINST_POP_POV	AHRF_TOT_OB_GYN	AHRF_TOT_MED_SPEC	ACS_TOT_HU	CRDC_TOT_STUD_ASN_F	ACS_TOT_HH	OPP_TOP20_WHT_F_HH_75PT	ACS_PCT_OWNER_HU_COST_30PCT	AHRF_TOT_OPHTHALMOLOGY	AHRF_TOT_RADI	CCD_TOT_STUDENTS	AHRF_TOT_SURG_SPECS	AHRF_CARDIOVAS_SPEC_RATE	AHRF_PULMONARY_SPEC_RATE	CRDC_TOT_PRESCHOOL_MTR_M	LTC_TOT_RESIDENTS	ACS_TOT_POP_ABOVE25	AHRF_TOT_GEN_INTERNAL_MED	CRDC_TOT_STUD_ASN_M	AHRF_MARKET_ENROL_NEW	ACS_TOT_CIVIL_POP_ABOVE18	CCBP_FF_RATE	ACS_TOT_POP_ABOVE16	ACS_TOT_POP_ABOVE15	AHRF_TOT_NURSE_PRACT	AHRF_TOT_OTOLARYNGOLOGY	ACS_TOT_POP_ABOVE5	AHRF_TOT_ADV_NURSES	AHRF_TOT_CARDIOVAS_SPEC	AHRF_TOT_PSYCH	AHRF_TOT_UROL	ACS_TOT_POP_WT	ACS_TOT_POP_POV	ACS_TOT_OWN_CHILD_BELOW17	AHRF_TOT_PULMONARY_SPEC	NHC_AVG_REP_NURSE_STAFF	AHRF_RET_DEST_USDA	OPP_INCAR_BLK_M_HH_50PT	ACS_PCT_POP_SAME_SEX_SPOUSE	OPP_TOP20_BLK_F_HH_75PT	SEDA_CS_TOT_MATH_GR8_ALL	ACS_PCT_MULT_RACE	SEDA_CS_TOT_MATH_GR3_ALL	AHRF_TOT_HOSP_TELE_ICU	POS_TOT_HOSP_REHAB	ACS_MEDIAN_HH_INC_HISP	AHRF_TOT_GENRL_SURG	POS_HOSP_CHEMO_RATE	AMFAR_TOT_MEDSAFAC	CCBP_BWLSTORES_RATE	ACS_TOT_POP_16_19	AHRF_TXC_SITE_CNTRL	AHRF_TOT_CLIN_NURSE_SPEC	AHRF_PRESC_ENROLLMENT	AHRF_TOT_COLON_SRG	CRDC_TOT_PRESCHOOL_ASN_F	AMFAR_SSP	AHRF_OTOLARYNGOLOGY_RATE	POS_TOT_ASC	AHRF_GENRL_SURG_RATE	AHRF_TOT_MDCR_FFS_ACT_COST	AHRF_TOT_PLASTIC_SURG	OPP_TOP20_OTHER_M_HH_25PT	LTC_TOT_BEDS	AMFAR_TOT_HCVTFAC	CRDC_TOT_FTENURSE	AHRF_TOT_MDCR_FFS_STD_COST	ACS_MEDIAN_HH_INC_NHPI	OPP_TOP20_HSP_F_HH_1PT	ACS_MEDIAN_AGE_MALE	POS_MIN_DIST_CLINIC	AHRF_UROL_RATE	CRE_TOT_RISK3	ACS_PCT_HOUSEHOLDER_MULT	ACS_PCT_AGE_50_64	AHRF_NEUROLOGICAL_SURG_RATE	CRDC_TOT_SUSP_IDEA_LEP	AHRF_TOT_NEONATALIC_HOSP	AHRF_TOT_THORACIC_SURG	ACS_PCT_HISP_FEMALE	CCBP_SOGS_RATE	CRDC_TOT_FTEPSY	ACS_PCT_AGE_ABOVE80	OPP_TOP20_ASN_M_HH_1PT	AHRF_TOT_NEUROLOGICAL_SURG	AHRF_FARM_DEP_USDA	AHRF_TOT_HOSP_TELE_STROKE	CRDC_TOT_FTESOC	AHRF_TOT_N_ST_G_PAYRLL_1000	CRDC_PCT_SATACT_LEP	SEDA_MATH_GR3_WAG	CRDC_TOT_PRESCHOOL_MTR_F	AHRF_ECO_DEP_USDA	CRDC_TOT_STUD_LEP	AMFAR_TOT_HIVHCVTFAC	POS_TOT_HOSP_ALC	SEDA_ELA_GR3_WAG	NHC_AVG_LIC_STAFF	ACS_PCT_INC50_ABOVE65	ACS_PCT_POP_SAME_SEX_UNMRD_P	MGV_PCT_BEN_FFS_WHITE	AHRF_TOT_ARBRNE_ST_G_ISO_ROOMS	CRDC_TOT_SUSP_IDEA	ACS_PCT_HU_UTILITY_GAS	CAF_ADJ_COUNTY_8	SEDA_CS_MN_MATH_GR8_HSP	POS_TOT_HOSP_PED_ICU	SEDA_ELA_GR3_NEG	SEDA_ELA_GR8_NEG	AHRF_TOT_OPRT_ROOM	SEDA_CS_MN_ELA_GR3_HSP	CRDC_TOT_STUD_HIS_M	CRDC_TOT_STUD_HIS_F	CRDC_TOT_SUSP_LEP	AHRF_TOT_ARBRNE_ST_G_ISO_HOSPS	AHRF_TOT_ST_COMM_HOSP_ADMS	AHRF_TOT_MEDSURGIC_HOSP	SEDA_CS_TOT_MATH_GR8_HSP	CDCAP_HIVDIAG_AIAN_RATE_ABOVE13	POS_TOT_SNF_BEDS	AMFAR_TOT_HIVTFAC	CRDC_TOT_PRESCHOOL	AHRF_TOT_ER_VST_ST_G_HOSP	CRDC_TOT_PRESCHOOL_NHPI_M	EPAA_2NDMAX_CO_1HR	OPP_TOP20_ASN_M_HH_25PT	NHC_AVG_ADJ_NURSE_STAFF	ACS_PCT_BLACK_MALE	AHRF_TOT_ST_G_HOSP_ADMS	SEDA_CS_TOT_ELA_GR3_HSP	CRDC_TOT_PRESCHOOL_NHPI_F	AMFAR_TOT_MEDHCVTFAC	OPP_TOP20_HSP_F_N	AHRF_TOT_HOSP_ADMISSIONS	AHRF_MARKET_ENROL_150	NEPHTN_PCT_MODPD_PM25	OPP_TOP20_BLK_M_HH_75PT	POS_TOT_HOSP_ED	OPP_TOP20_OTHER_M_HH_1PT	ACS_MEDIAN_HH_INC_AIAN	AHRF_TOT_MCR_IP_DAY_ST_G	ACS_PCT_SAME_SEX_UNMRD_PRTNR	CRDC_TOT_CHARTER	OPP_TOP20_HSP_M_N	POS_ASC_RATE	SEDA_CS_TOT_MATH_GR3_HSP	CRDC_TOT_MAGNET	AHRF_TOT_N_ST_G_EXP	AHRF_TOT_N_ST_G_PAYRLL	AHRF_DAYS_AIR_QLT	ACS_PCT_HU_WOOD	OPP_INCAR_ASN_F_N	AHRF_GEN_PREV_RATE	AHRF_TOT_ST_COMM_HOSP	SEDA_CS_TOT_ELA_GR8_HSP	CRDC_TOT_FTETEACH_NOTCERT	AHRF_TOT_NURSE_ANESTH	OPP_TOP20_HSP_F_HH_50PT	AHRF_TOT_ST_G_HOSP	AHRF_COLON_SRG_RATE	OPP_INCAR_ASN_M_N	AMFAR_TOT_AMATFAC	ACS_PCT_RENTER_HU_ABOVE65	CRDC_TOT_PRESCHOOL_HIS_M	AHRF_TOT_NEONATALIC_BEDS	AMFAR_TOT_MEDHIVHCVTFAC	AHRF_TOT_HOSPS	AHRF_TOT_HOSP_BED	ACS_MEDIAN_AGE	CCBP_LARGE_INDUSTRY	AHRF_TOT_MEDSURGIC_BEDS	AHRF_TOT_ST_G_HOSP_BED	FEA_TOT_WIC_STORES	POS_TOT_HOSP_MEDSURG_ICU	SEDA_CS_TOT_ELA_GR3_ECD	POS_TOT_HOSP_PSYCH	OPP_TOP20_BLK_M_N	AHRF_TOT_HOSP_MOBILE	ACS_PCT_AGE_45_64	OPP_TOP20_BLK_F_N	CDCAP_HIVDIAG_BLK_RATE_ABOVE13	CCD_TOT_STATE_REVENUE	CCBP_SA_RATE	CRDC_TOT_FIREARM	AHRF_TXC_SITE_NO_DATA	SEDA_CS_TOT_ELA_GR8_ECD	ACS_PCT_TAXICAB_2WORK	ACS_PCT_COMMT_15MIN	CHR_PCT_ALCOHOL_DRIV_DEATH	NOAAS_TOT_HAIL	AHRF_TOT_MCR_BN_READM	CRDC_TOT_PRESCHOOL_HIS_F	CRE_RATE_RISK12	ACS_PCT_OTHER_FEMALE	CEN_POPDENSITY_COUNTY	ACS_PCT_OTHER_NONHISP	AMFAR_TOT_MEDAMATFAC	AHRF_TOT_CARDIAC_IC_HOSP	POS_MAX_DIST_ED	ACS_PCT_PVT_EMPL_DRCT_BELOW64	ACS_PCT_NHPI_NONHISP	CCD_STATE_REVENUE_LUNCH	AMFAR_TOT_MEDHIVTFAC	CRDC_TOT_DIST_ENROLL	ACS_PCT_NHPI	ACS_PCT_PVT_EMPL_DRCT	NEPHTN_PCT_MONPD_PM25	ACS_PCT_NHPI_COMB	SAIPE_TOT_POV	OPP_INCAR_NAM_F_HH_50PT	SEDA_CS_TOT_MATH_GR3_ECD	OPP_TOP20_HSP_M_HH_25PT	ACS_PCT_HOUSEHOLDER_NHPI	AHRF_TOT_COM_HEALTH_GRANT	CEN_AREALAND_SQM_COUNTY	AHRF_DUAL_ELIG	ACS_PCT_OTH_LANG	CRDC_PCT_LAW_REFERRAL	AHRF_THORACIC_SURG_RATE	ACS_PCT_OWNER_HU_COST_50PCT	CRDC_TOT_STUD_NHPI_F	AHRF_TOT_MDCD_IP_DAY_ST_G	ACS_PCT_HH_OTHER_COMP	AHRF_TOT_CARDIAC_IC_BEDS	AHRF_MEDICAID_MALE_ELIG	NOAAS_TOT_WILDFIRE	AHRF_CLIN_NURSE_SPEC_RATE	POS_TOT_HOSP_BURN	SEDA_CS_TOT_MATH_GR8_ECD	CRDC_TOT_STUD_NHPI_M	OPP_INCAR_BLK_M_N	OPP_INCAR_NAM_F_HH_100PT	EPAA_2NDMAX_PM10_24HR	OPP_INCAR_NAM_F_HH_75PT	ACS_MEDIAN_HH_INC_OTHER	POS_HOSP_MEDSURG_ICU_RATE	AHRF_MEDICAID_ELIG	OPP_INCAR_HSP_F_N	NOAAS_TOT_WIND	AMFAR_MEDSAFAC_RATE	OPP_INCAR_NAM_F_HH_25PT	AHRF_TOT_STNG_LT_HOSP_ADMS	AMFAR_TOT_RWFAC	SEDA_ELA_GR8_WAG	OPP_INCAR_NAM_M_HH_75PT	OPP_TOP20_BLK_F_HH_100PT	ACS_PCT_PUB_COMMT_59MIN	ACS_TOT_GRANDCHILDREN_GP	POS_TOT_SNF	OPP_INCAR_HSP_M_N	AHRF_MEDICAID_FEMALE_ELIG	ACS_PCT_MALE	ACS_PCT_AGE_ABOVE65	SEDA_CS_TOT_ELA_GR8_BLK	POS_TOT_NF	POS_HOSP_REHAB_RATE	OPP_INCAR_BLK_F_N	OPP_TOP20_ASN_F_HH_1PT	OPP_TOP20_ASN_M_HH_50PT	ACS_PCT_GULFWAR_2001	CRDC_TOT_RAPE_ASSAULT	SAIPE_TOT_POV_0_17	CEN_AIAN_NH_IND	OPP_TOP20_ASN_F_HH_25PT	SAIPE_TOT_POV_5_17	AHRF_TOT_ST_N_G_HOSP	FEA_TOT_FDPIR	AHRF_TOT_NHSC_ACTIVE	OPP_TOP20_OTHER_M_HH_50PT	LTC_OCCUPANCY_RATE	SEDA_CS_TOT_ELA_GR3_BLK	PC_PCT_MCARE_MAY_ACPT_APPRVD_AMT	OPP_TOP20_NAM_F_HH_1PT	CRDC_TOT_STUD_AIAN_F	CRDC_TOT_STUD_AIAN_M	POS_HOSP_ED_RATE	AHRF_TOT_LT_HOSP	AHRF_HOSP_TEACHING	POS_TOT_FQHC	SEDA_CS_TOT_MATH_GR3_BLK	AMFAR_HCVTFAC_RATE	ACS_PCT_VET_COLLEGE	OPP_INCAR_BLK_F_HH_25PT	OPP_TOP20_OTHER_F_HH_75PT	POS_MAX_DIST_ALC	OPP_TOP20_HSP_M_HH_1PT	ACS_MEDIAN_HH_INC_ASIAN	POS_MAX_DIST_MEDSURG_ICU	AHRF_TOT_OUTPAT_VST_STNGH	AHRF_TOT_NHSC_FTE_PROV	OPP_TOP20_ASN_F_HH_50PT	OPP_INCAR_BLK_F_HH_1PT	CAF_ADJ_COUNTY_9	SEDA_CS_TOT_MATH_GR8_BLK	POS_TOT_NF_BEDS	ACS_PCT_PUB_COMMT_60MINUP	AHRF_OP_VST_ST_G_OTHR_RATE	NEPHTN_ARSENIC_MEAN_POP	SEDA_CS_MN_MATH_GR8_NAM	POS_TOT_HHA	ACS_MEDIAN_AGE_FEMALE	CCBP_PHYS_RATE	AHRF_HOSP_TELE_ICU_RATE	ACS_PCT_WHITE_MALE	AMFAR_MEDHCVTFAC_RATE	OPP_INCAR_NAM_F_HH_1PT	AHRF_TOT_N_ST_G_EXP_1000	CDCSVI_RPL_THEME3_MINO	POS_PCT_HOSP_GOV	AHRF_TOT_HOSP_BEDS_LT	POS_TOT_HOSPICE	CRDC_TOT_SUSP	ACS_PCT_NATURE	POS_MIN_DIST_ED	CRDC_TOT_STUD_BLK_M	CRDC_TOT_STUD_BLK_F	ACS_PCT_PRIVATE_OTHER_BELOW64	AHRF_NEONATALIC_BEDS_RATE	AHRF_TXC_SITE_NO_CNTRL	AHRF_TOT_ARBRNE_STNGLT_ISO_ROOM	ACS_PCT_WHOLESALE	POS_TOT_CMHC	ACS_PCT_NVR_MARRIED_F	ACS_PCT_PRIVATE_OTHER	OPP_INCAR_BLK_M_HH_75PT	ACS_PCT_HH_PC_ONLY	AMFAR_HIVHCVTFAC_RATE	OPP_INCAR_NAM_M_HH_100PT	NOAAS_TOT_DEATHS_INDIRECT	SEDA_MATH_GR8_WMG	OPP_INCAR_HSP_M_HH_25PT	POS_HOSP_ALC_RATE	POS_MEAN_DIST_ED	HHC_PCT_HHA_OCC_THERAPY	NOAAS_TOT_HURRICANE_STORM	HHC_PCT_HHA_SPEECH	AHRF_OP_VST_ST_G_ER_OP_RATE	AMFAR_MEDHIVHCVTFAC_RATE	AHRF_PCT_GOOD_AQ	AHRF_TOT_NH_BED_STNGH	CDCP_CHOLES_SCR_ADULT_C	CRDC_PCT_SATACT_IDEA	CRDC_TOT_SCH_FIREARM	OPP_TOP20_ASN_F_HH_75PT	AHRF_NURSE_ANESTH_RATE	CRDC_TOT_PRESCHOOL_BLK_M	MMD_ED_VISITS_AIAN_RATE	ACS_PCT_OWNER_HU	ACS_PCT_NVR_MARRIED_M	OPP_TOP20_BLK_M_HH_100PT	CRDC_PCT_HBA_SEX_STUDENTS	AHRF_ARBRNE_ST_G_ISO_ROOMS_RATE	POS_MEDIAN_DIST_ED	NEPHTN_SEX_RATIO_RATE	AHRF_HOSPS_RATE	EPAA_2NDMAX_CO_8HR	MGV_PER_CAPITA_ACTUAL_HC	AHRF_ST_G_HOSP_RATE	FEA_WIC_STORES_PER_1000	AHRF_ST_COMM_HOSP_RATE	NOAAS_TOT_INJURIES_INDIRECT	ACS_PCT_ASIAN_FEMALE	NOAAS_TOT_FLOOD	AHRF_LT_HOSP_RATE	MMD_ACUTE_PQI_HISP_RATE	OPP_TOP20_NAM_F_HH_25PT	POS_HOSP_BURN_RATE	NOAAS_TOT_DEATHS_DIRECT	SEDA_ELA_GR8_WMG	AHRF_OPRT_ROOM_RATE	OPP_TOP20_HSP_F_HH_75PT	OPP_TOP20_HSP_M_HH_50PT	CRDC_TOT_PRESCHOOL_BLK_F	OPP_INCAR_ASN_M_HH_1PT	SEDA_CS_MN_MATH_GR3_HSP	NOAAS_PROPERTY_DAMAGE	HHC_PCT_HHA_MEDICAL	ACS_AVG_HH_SIZE	ACS_PCT_NHPI_MALE	POS_MEAN_DIST_ALC	NOAAS_TOT_DROUGHT	AHRF_HOSP_MOBILE_RATE	AHRF_ARBRNE_ST_G_ISO_HOSPS_RATE	ACS_PCT_1UP_RENT_1ROOM	OPP_INCAR_ASN_M_HH_25PT	POS_MIN_DIST_ALC	OPP_INCAR_NAM_M_N	ACS_PCT_HH_DIAL_INTERNET_ONLY	OPP_INCAR_HSP_M_HH_1PT	AHRF_CARDIAC_IC_HOSP_RATE	POS_MAX_DIST_OBSTETRICS	AHRF_IP_DAY_ST_G_HOSP_RATE	AMFAR_HIVTFAC_RATE	SEDA_CS_TOT_MATH_GR8_NAM	POS_MEDIAN_DIST_ALC	ACS_PCT_AIAN_FEMALE	ACS_PCT_1UP_PERS_1ROOM	SEDA_CS_TOT_MATH_GR3_NAM	AHRF_CARDIAC_IC_BEDS_RATE	CDCAP_HIVDIAG_WHT_RATE_ABOVE13	AHRF_OP_VST_LT_ER_OP_RATE	LTC_AVG_PCT_MEDICARE	MMD_ACUTE_PQI_OTHER_RATE	POS_HOSP_PED_ICU_RATE	ACS_PCT_VACANT_HU	AHRF_NEONATALIC_HOSP_RATE	POS_MIN_DIST_MEDSURG_ICU	AHRF_GOV_DEP_USDA	ACS_PCT_POV_ASIAN	POS_MEAN_DIST_MEDSURG_ICU	ACS_PCT_MULT_RACE_MALE	AHRF_ARBRNE_STNGLT_ISO_ROOM_RATE	OPP_TOP20_HSP_F_HH_100PT	AMFAR_SSP_RATE	CDCP_CHOLES_SCR_ADULT_A	OPP_INCAR_ASN_M_HH_50PT	OPP_TOP20_OTHER_F_HH_100PT	AHRF_IP_DAY_NH_HOSP_RATE	CRDC_TOT_TRANSFER	AHRF_SURG_OPRN_IP_RATE	AMFAR_MEDHIVTFAC_RATE	AHRF_NH_BED_STNGH_RATE	ACS_PCT_AIAN	OPP_TOP20_NAM_M_N	ACS_PCT_HOUSEHOLDER_AIAN	NHC_FACS_RATE	SEDA_CS_TOT_ELA_GR3_NAM	POS_HOSP_PSYCH_RATE	EPAA_MEAN_NO2_1HR	CHR_SEGREG_NON_WHITE	POS_MEDIAN_DIST_MEDSURG_ICU	ACS_PCT_ARMED_FORCES	CRDC_PCT_HBA_DISABLE_STUDENTS	ACS_PCT_1UP_OWNER_1ROOM	CCBP_CFS_RATE	AHRF_HOSP_TELE_STROKE_RATE	CCBP_GAMBLING_RATE	ACS_PCT_AIAN_NONHISP	AMFAR_MEDAMATFAC_RATE	OPP_INCAR_NAM_F_N	ACS_PCT_HH_ABOVE65	OPP_INCAR_BLK_F_HH_50PT	MGV_PER_CAPITA_STD_HC	POS_PCT_HOSP_NON_PROFIT	ACS_PCT_WHITE_NONHISP	AMFAR_AMATFAC_RATE	AHRF_SURG_OPRN_OP_RATE	AMFAR_RWFAC_RATE	LTC_PCT_MULTI_FAC	OPP_TOP20_NAM_F_N	OPP_TOP20_NAM_M_HH_1PT	ACS_PCT_CONSTRUCT	CRDC_TOT_PRESCHOOL_AIAN_M	MMD_CHRONIC_PQI_OTHER_RATE	CRDC_PCT_HBA_RACE_STUDENTS	SEDA_MATH_GR3_WMG	EPAA_98PR_NO2_1HR	SEDA_CS_TOT_ELA_GR8_NAM	AHRF_HOSP_BEDS_LT_RATE	ACS_PCT_AIAN_COMB	EPAA_2NDMAX_O3_1HR	ACS_PCT_MULT_RACE_FEMALE	AHRF_NHSC_FTE_PROV_RATE	AHRF_IP_DAY_STNG_LT_RATE	CRDC_TOT_PRESCHOOL_AIAN_F	ACS_PCT_IN_STATE_MOVE	MMD_ACUTE_PQI_ASIAN_RATE	OPP_INCAR_OTHER_F_HH_25PT	AMFAR_MHFAC_RATE	ACS_PCT_TRICARE_VA_BELOW64	ACS_PCT_AGE_18_29	NOAAS_TOT_INJURIES_DIRECT	OPP_INCAR_HSP_M_HH_50PT	POS_HOSP_AMBULANCE_RATE	ACS_PCT_AIAN_MALE	HHC_PCT_HHA_NURSING	CRDC_PCT_SATACT	HHC_PCT_HHA_AIDE	ACS_PCT_TRICARE_VA	SEDA_ELA_GR3_WMG	ACS_PCT_HU_BUILT_1979	HHC_PCT_HHA_PHYS_THERAPY	ACS_PCT_OWNER_HU_CHILD	SEDA_CS_MN_ELA_GR8_NAM	OPP_INCAR_OTHER_F_HH_1PT	ACS_MEDIAN_YEAR_BUILT	CRDC_TOT_TRANSFER_IDEA	ACS_PCT_PUB_COMMT_29MIN	ACS_PCT_HU_COAL	ACS_PCT_VET	NEPHTN_MAXDROUGHT	OPP_INCAR_ASN_M_HH_75PT	ACS_PCT_HH_OTHER_COMP_ONLY	OPP_TOP20_ASN_M_HH_75PT	PIAAC_NUM_PCT_LEVEL2	MMD_PERSONALITY_DISD	ACS_PCT_NHPI_FEMALE	EPAA_MEAN_WTD_PM10	AHRF_HPSA_MENTAL	ACS_PCT_POV_AIAN	AHRF_ST_G_HOSP_BED_RATE	POS_TOT_HOSP_AMBULANCE	OPP_INCAR_BLK_M_HH_100PT	ACS_PCT_ADMIN	OPP_INCAR_ASN_M_HH_100PT	EPAA_98PR_PM25_DAILY	AHRF_ADV_NURSES_RATE	OPP_TOP20_HSP_M_HH_100PT	OPP_TOP20_WHT_M_HH_100PT	ACS_PCT_OTHER	AHRF_HOSP_BED_RATE	AMFAR_MEDMHFAC_RATE	ACS_PCT_COMMT_29MIN	ACS_PCT_ASIAN_MALE	OPP_TOP20_OTHER_M_HH_75PT	POS_NF_RATE	ACS_PCT_MULT_RACE_NONHISP	AHRF_NHSC_ACTIVE_RATE	MMD_OVERALL_PQI_OTHER_RATE	ACS_PCT_GULFWAR_1990_2001	OPP_TOP20_HSP_M_HH_75PT	OPP_INCAR_BLK_F_HH_100PT	AHRF_COM_HEALTH_GRANT_RATE	ACS_PCT_RENTER_HU	POS_MIN_DIST_OBSTETRICS	ACS_PCT_VIETNAM	AHRF_HPSA_PRIM	ACS_PCT_HU_BOT_TANK_LP_GAS	OPP_INCAR_OTHER_M_HH_50PT	AMFAR_AVG_DISTMAT	OPP_INCAR_BLK_F_HH_75PT	ACS_PCT_WORK_NO_CAR	CDCAP_SYPHILIS_RATE	ACS_PCT_CTZ_ABOVE18	POS_RHC_RATE	AHRF_MEDSURGIC_HOSP_RATE	POS_MEAN_DIST_OBSTETRICS	EPAA_99PR_SO2_1HR	OPP_INCAR_HSP_F_HH_1PT	OPP_TOP20_ASN_F_HH_100PT	ACS_PCT_AGE_18_44	AHRF_POP_LOSS_USDA	ACS_PCT_HEALTH_INC_200_399	OPP_INCAR_OTHER_M_HH_75PT	OPP_TOP20_OTHER_M_HH_100PT	CDCAP_HIVDIAG_HIS_RATE_ABOVE13	ACS_PCT_IN_COUNTY_MOVE	ACS_PCT_PRIVATE_MDCR	MMD_CHRONIC_PQI_ASIAN_RATE	POS_MAX_DIST_TRAUMA	AHRF_ST_N_G_HOSP_RATE	ACS_PCT_GOVT	POS_MAX_DIST_PED_ICU	POS_MEDIAN_DIST_OBSTETRICS	OPP_INCAR_OTHER_M_HH_25PT	AHRF_MEDSURGIC_BEDS_RATE	OPP_INCAR_ASN_F_HH_100PT	NEPHTN_PCT_ARSENIC_MCL_LESS10	CDCAP_HIVDIAG_NHPI_RATE_ABOVE13	OPP_INCAR_OTHER_M_HH_100PT	CDCW_SELFHARM_DTH_RATE	ACS_PCT_EDUC	MMD_OVERALL_PQI_ASIAN_RATE	CRDC_PCT_GTENR_STUDENTS	ACS_PCT_WHITE_FEMALE	NOAAS_TOT_TORNADO	ACS_PCT_POV_NHPI	OPP_INCAR_OTHER_M_HH_1PT	AHRF_HPSA_DENTIST	AHRF_TOT_RURL_REFRRL_CNT	OPP_INCAR_ASN_F_HH_75PT	OPP_TOP20_NAM_M_HH_25PT	OPP_INCAR_HSP_F_HH_25PT	OPP_INCAR_WHT_M_HH_75PT	AHRF_NURSE_PRACT_RATE	MMD_CHRONIC_PQI_HISP_RATE	CCBP_LAB_RATE	NEPHTN_NUMDROUGHT	OPP_INCAR_WHT_M_HH_100PT	OPP_TOP20_WHT_F_HH_100PT	AHRF_RURL_REFRRL_CNT_RATE	ACS_PCT_AGE_30_44	OPP_INCAR_WHT_F_HH_1PT	ACS_PCT_RETAIL	MMD_ED_VISITS_BLACK_RATE	ACS_PCT_AGE_5_9	ACS_PCT_COMMT_60MINUP	OPP_TOP20_NAM_F_HH_50PT	OPP_INCAR_HSP_M_HH_75PT	EPAA_2NDMAX_SO2_24HR	ACS_PCT_FEMALE	ACS_PCT_AGE_15_17	PC_PCT_MEDICARE_APPRVD_FULL_AMT	ACS_PCT_AGE_10_14	POS_MEAN_DIST_PED_ICU	AHRF_MINE_DEP_USDA	OPP_INCAR_WHT_F_HH_100PT	ACS_PCT_COMMT_59MIN	POS_MEDIAN_DIST_PED_ICU	CDCAP_HIVDIAG_M_RATE_ABOVE13	POS_FQHC_RATE	NEPHTN_PCT_ARSENIC_MCL_GREATER10	POS_MIN_DIST_PED_ICU	NOAAS_TOT_HEAT_EVENTS	ACS_PCT_RENTER_HU_COST_50PCT	EPAA_4THMAX_O3_8HR	POS_MEAN_DIST_TRAUMA	AHRF_NONSP_DEP_USDA	OPP_INCAR_WHT_M_HH_1PT	POS_SNF_BEDS_RATE	POS_MEDIAN_DIST_TRAUMA	OPP_INCAR_OTHER_F_HH_50PT	LTC_AVG_OBS_MEDIAN_LOS	ACS_PCT_OTHER_MALE	OPP_INCAR_WHT_F_HH_75PT	POS_MIN_DIST_TRAUMA	OPP_TOP20_ASN_M_HH_100PT	ACS_PCT_HH_1PERS	POS_HOSPICE_RATE	ACS_PCT_GRP_QRT	ACS_PCT_VET_UNEMPL_18_64	SAHIE_PCT_UNINSURED64_138FPL	LTC_AVG_DAILY_CENSUS	POS_HHA_RATE	CDCAP_HIV_RATE_ABOVE13	OPP_INCAR_WHT_F_HH_25PT	AMFAR_PCT_DRUGDEP_ABOVE12	ACS_PCT_GRANDP_RESPS_P	SAHIE_PCT_UNINSURED64_200FPL	NEPHTN_TEMPERATURE_105	MMD_OVERALL_PQI_HISP_RATE	OPP_INCAR_HSP_F_HH_100PT	OPP_INCAR_HSP_F_HH_50PT	ACS_PCT_POV_OTHER	POS_CMHC_RATE	OPP_INCAR_WHT_M_HH_50PT	OPP_INCAR_WHT_F_HH_50PT	OPP_INCAR_WHT_M_HH_25PT	POS_PCT_HOSP_FOR_PROFIT	OPP_INCAR_HSP_F_HH_75PT	ACS_PCT_BLACK_FEMALE	NOAAC_PRECIPITATION_JUN	MMD_ED_VISITS_ASIAN_RATE	MMD_CHRONIC_PQI_AIAN_RATE	MGV_PER_CAPITA_ACTUAL_EM	ACS_PCT_HH_ALONE_ABOVE65	OPP_INCAR_OTHER_F_HH_100PT	ACS_PCT_PUB_COMMT_15MIN	MMD_ED_VISITS_OTHER_RATE	ACS_PCT_RENTER_HU_COST_30PCT	SAHIE_PCT_UNINSURED64_138_400FPL	CCBP_PCT_HEALTH_EMPLOYMENT	CDCAP_HIVDIAG_RATE_ABOVE13	OPP_INCAR_ASN_F_HH_50PT	ACS_PCT_AGE_0_17	OPP_INCAR_HSP_M_HH_100PT	POS_NF_BEDS_RATE	SAHIE_PCT_UNINSURED64_250FPL	OPP_INCAR_OTHER_F_HH_75PT	OPP_TOP20_NAM_F_HH_75PT	CCBP_CHS_RATE	ACS_PCT_HISP_MALE	ACS_PCT_OTHER_INS	CCBP_SHELTERS_RATE	EPAA_MAX_PB_3MON	ACS_PCT_GULFWAR_VIETNAM	CRDC_PCT_CTY_KGTN	MMD_READM_BLACK_RATE	OPP_INCAR_ASN_F_HH_25PT	MMD_OVERALL_PQI_AIAN_RATE	ACS_PCT_POV_BLACK	OPP_TOP20_NAM_M_HH_100PT	MMD_READM_HISP_RATE	ACS_PCT_PUBLIC_OTHER	OPP_INCAR_ASN_F_HH_1PT	OPP_TOP20_NAM_F_HH_100PT	NOAAC_PRECIPITATION_SEP	ACS_PCT_AGE_0_4	HRSA_MUA_COUNTY	SEDA_CS_MN_MATH_GR3_NAM	LTC_TOT_RESIDENTS_RATE	MMD_READM_ASIAN_RATE	SEDA_CS_MN_ELA_GR3_NAM	OPP_TOP20_NAM_M_HH_50PT	ACS_PCT_POV_WHITE	ACS_PCT_HU_KITCHEN	OPP_TOP20_NAM_M_HH_75PT	ACS_PCT_HH_SAT_INTERNET	ACS_PCT_HU_NO_VEH	ACS_PCT_INC50	EPAA_MEAN_SO2_1HR	MMD_ACUTE_PQI_AIAN_RATE	NOAAC_PRECIPITATION_OCT	LTC_AVG_ACUITY_INDEX	AHRF_MANF_DEP_USDA	CRDC_PCT_STUD_DESEGPLAN	NEPHTN_TEMPERATURE_100	CRDC_PCT_LEA_DESEGPLAN	MMD_CHRONIC_PQI_BLACK_RATE	LTC_TOT_BEDS_RATE	MMD_READM_AIAN_RATE	NOAAC_PRECIPITATION_AUG	ACS_PCT_POV_HISPANIC	MMD_READM_OTHER_RATE	POS_SNF_RATE	CDCAP_HIVDIAG_MTR_RATE_ABOVE13	ACS_PCT_HH_INTERNET_NO_SUBS	MMD_READM_F_RATE	ACS_GINI_INDEX	MGV_PER_CAPITA_STD_EM	ACS_PCT_PVT_PROFIT	MMD_READM_M_RATE	MGV_PER_CAPITA_ACTUAL_IP	ACS_PCT_HH_TABLET_ONLY	AHRF_USDA_RUCC_2013	SAHIE_PCT_UNINSURED64_400FPL	MMD_READM_WHITE_RATE	NCHS_URCS_2006	ACS_PCT_PUBLIC_OTHER_BELOW64	CCBP_EORS_RATE	LTC_AVG_PCT_PRESSURE_ULCER	CDCAP_TUBERCULOSIS_RATE	CRDC_PCT_COUNTY_PREK	ACS_PCT_POV_MULTI	AHA_HHI_SHRTTRM_ACUTE_LOS_CTY	ACS_PCT_MARRIED_SP_AB_M	POS_TOT_RHC	ACS_PCT_HU_PLUMBING	CDCA_PREV_DTH_HISP_RATE_BELOW74	ACS_PCT_GRANDP_RESPS_NO_P	CRDC_PCT_CTY_PSTITLEI	MMD_ED_VISITS_HISP_RATE	AHA_HHI_SHRTTRM_ACUTE_ADMSN_CTY	MMD_OVERALL_PQI_BLACK_RATE	NCHS_URCS_2013	FEA_WIC_REDEMP_PER_STORE	AHA_HHI_SHRTTRM_ACUTE_DSCHR_CTY	CDCAP_HIVDIAG_F_RATE_ABOVE13	ACS_PCT_VET_POV_18_64	ACS_PCT_NO_WORK_NO_SCHL_16_19	CCBP_HOME_RATE	ACS_PCT_TRANSPORT	AHA_HHI_SHRTTRM_ACUTE_DSCHR_CBSA	AHA_HHI_SHRTTRM_ACUTE_LOS_CBSA	AHA_HHI_SHRTTRM_ACUTE_ADMSN_CBSA	ACS_PCT_HH_CELLULAR_ONLY	ACS_PCT_MEDICARE_ONLY	ACS_PCT_HH_NO_FD_STMP_BLW_POV	CCD_TOT_FED_REVENUE	NOAAC_PRECIPITATION_NOV	CDCW_INJURY_DTH_RATE	NOAAC_PRECIPITATION_MAY	ACS_PCT_WIDOWED_M	ACS_PCT_RENTER_HU_CHILD	CCBP_CS_RATE	ACS_PCT_CHILD_DISAB	ACS_PCT_MEDICAID_ANY	ACS_PCT_PRIVATE_MDCR_35_64	AHRF_PCT_PRESC_PEN	ACS_PCT_MEDICAID_ANY_BELOW64	MMD_ACUTE_PQI_BLACK_RATE	NEPHTN_TEMPERATURE_95	ACS_PCT_INC50_BELOW17	NEPHTN_PCT_ARSENIC_MCL_NOTDETECT	NOAAC_PRECIPITATION_FEB	ACS_PCT_UNEMPLOY	LTC_PCT_FOR_PROFIT	NOAAC_PRECIPITATION_JUL	CRDC_PCT_CTY_PSLOWINC	CDCW_DRUG_DTH_RATE	ACS_PCT_HH_INC_10000	ACS_PCT_HH_FOOD_STMP_BLW_POV	CHR_VIOLENT_CRIME_RATE	ACS_PCT_NONVET_POV_18_64	ACS_PCT_PUBLIC_ONLY	CDCW_OPIOID_DTH_RATE	MMD_ED_VISITS_DUAL_RATE	ACS_PCT_MARRIED_SP_AB_F	NOAAC_PRECIPITATION_JAN	AMFAR_MME_PER_CAPITA	ACS_PCT_MANUFACT	CDC_USCS_AGE_ADJ_INC_RATE	MMD_BIPOLAR_DISD	MMD_ACUTE_PQI_M_RATE	ACS_PCT_DRIVE_2WORK	AHRF_UNEMPLOYED_RATE	ACS_PCT_PERSON_INC_BELOW99	CDCSVI_RPL_THEME4_HH_TRANS	ACS_PCT_VET_DISABLE_18_64	ACS_PCT_DIVORCED_F	NOAAC_PRECIPITATION_DEC	SAHIE_PCT_UNINSURED64	ACS_PCT_HH_INC_49999	NOAAC_PRECIPITATION_APR	ACS_PCT_HH_PUB_ASSIST	ACS_PCT_HH_FOOD_STMP	CDCA_BLOOD_HOSP_RATE_ABOVE65	MGV_PER_CAPITA_ACTUAL_PA	MMD_DEPR_DISD	CDCAP_CHLAMYDIA_RATE	ACS_PCT_PERSON_INC_100_124	ACS_PCT_HEALTH_INC_138_199	ACS_PCT_UNINSURED	AHRF_LOW_EDUC_USDA	ACS_PCT_CHILD_1FAM	CDCAP_GONORRHEA_RATE	ACS_PCT_UNINSURED_BELOW64	ACS_PCT_HEALTH_INC_BELOW137	NOAAC_PRECIPITATION_MAR	ACS_PCT_HH_SMARTPHONE_ONLY	ACS_PCT_CTZ_US_BORN	ACS_PCT_HH_KID_1PRNT	ACS_PCT_HH_NO_COMP_DEV	NOAAC_MAX_TEMP_JUL	AMFAR_PCT_NONMEDPAIN_ABOVE12	ACS_PCT_PERSON_INC_125_199	NEPHTN_AVG_MONAAAC_PM25	EPAA_MEAN_WTD_PM25	CDCP_BLOOD_MED_ADULT_C	ACS_PCT_ENGLISH	CRDC_PCT_RETAIN	NEPHTN_TEMPERATURE_90	ACS_PCT_HH_1FAM_FOOD_STMP	MGV_PCT_BEN_FFS_BLACK	ACS_PCT_HU_ELEC	MMD_OUD_IND	NOAAC_MAX_TEMP_JAN	NOAAC_MIN_TEMP_JAN	LTC_AVG_OBS_REHOSP_RATE	NOAAC_AVG_TEMP_JAN	ACS_PCT_DIVORCED_M	AHRF_HIGH_POV_USDA	NOAAC_MAX_TEMP_FEB	ACS_PCT_NOT_LABOR	NOAAC_AVG_TEMP_FEB	ACS_PCT_WIDOWED_F	NEPHTN_HEATIND_105	NOAAC_MIN_TEMP_FEB	NOAAC_MAX_TEMP_DEC	MMD_ACUTE_PQI_WHITE_RATE	MMD_ACUTE_PQI_F_RATE	MGV_PER_CAPITA_STD_PA	NOAAC_MIN_TEMP_OCT	NOAAC_MIN_TEMP_DEC	NOAAC_AVG_TEMP_DEC	AHRF_MCR_BN_READM_RATE	AMFAR_OPIOIDRX_RATE	ACS_PCT_BLACK_COMB	NOAAC_MAX_TEMP_MAR	NOAAC_MIN_TEMP_NOV	FEA_WIC_REDEMP_PER_CAPITA	ACS_PCT_HH_INC_14999	NOAAC_MAX_TEMP_AUG	AHRF_PER_POV_USDA	CDCP_DOCTOR_VISIT_ADULT_C	NOAAC_MAX_TEMP_OCT	NEPHTN_AVG_MODAAAC_PM25	ACS_PCT_VET_HS	NOAAC_AVG_TEMP_OCT	ACS_PCT_HOUSEHOLDER_BLACK	ACS_PCT_CHILDREN_GRANDPARENT	NOAAC_AVG_TEMP_MAR	ACS_PCT_HH_NO_INTERNET	NOAAC_MAX_TEMP_SEP	ACS_PCT_HH_INC_24999	NOAAC_AVG_TEMP_JUL	ACS_PCT_BLACK	MMD_ED_VISITS_MED_RATE	NOAAC_MIN_TEMP_MAR	WUSTL_AVG_PM25	NOAAC_AVG_TEMP_NOV	NEPHTN_HEATIND_100	CDCW_MATERNAL_DTH_RATE	CHR_FIREARM_DEATH_RATE	NOAAC_MAX_TEMP_NOV	LTC_PCT_RESD_BLACK	MMD_CHRONIC_PQI_WHITE_RATE	CDCP_ARTHRITIS_ADULT_C	LTC_AVG_PCT_MEDICAID	ACS_PCT_BLACK_NONHISP	NOAAC_MAX_TEMP_JUN	MMD_CHRONIC_PQI_M_RATE	NOAAC_MIN_TEMP_SEP	NOAAC_AVG_TEMP_SEP	AHRF_PER_CHLD_POV_USDA	ACS_PCT_LT_HS	MMD_OVERALL_PQI_M_RATE	NOAAC_MIN_TEMP_JUL	CDCW_TRANSPORT_DTH_RATE	NEPHTN_HEATIND_95	CDCP_DOCTOR_VISIT_ADULT_A	ACS_PCT_HS_GRADUATE	NOAAC_AVG_TEMP_AUG	AHRF_LOW_EMP_USDA	NOAAC_MIN_TEMP_APR	NEPHTN_HEATIND_90	MMD_ANXIETY_DISD	ACS_PCT_HU_MOBILE_HOME	ACS_PCT_DISABLE	CDCP_CHOLES_ADULT_C	NOAAC_MAX_TEMP_APR	NOAAC_MAX_TEMP_MAY	MMD_OVERALL_PQI_WHITE_RATE	NOAAC_AVG_TEMP_APR	MMD_ED_VISITS_WHITE_RATE	NOAAC_MIN_TEMP_AUG	MGV_PER_CAPITA_STD_IP	MMD_CHRONIC_PQI_F_RATE	NOAAC_AVG_TEMP_JUN	MMD_ED_VISITS_M_RATE	NOAAC_AVG_TEMP_MAY	CRE_RATE_RISK3	NOAAC_MIN_TEMP_MAY	NOAAC_MIN_TEMP_JUN	CDCP_KIDNEY_DISEASE_ADULT_C	MMD_OVERALL_PQI_F_RATE	CDCSVI_RPL_THEME2_HH_COMP	CHR_CHILD_DEATH_RATE	CCD_FED_REVENUE_CNA	CDCP_ASTHMA_ADULT_A	CDCP_ASTHMA_ADULT_C	MMD_ED_VISITS_F_RATE	PIAAC_LIT_PCT_LEVEL1_OR_BELOW	MMD_THREE_OR_MORE_COND	MGV_PCT_MEDICAID	AHRF_PREV_HOSP_RATE	CHR_PCT_LOW_BIRTH_WT	CHR_PCT_ADULT_OBESITY	CDCW_ASSAULT_DTH_RATE	ACS_PCT_NONVET_DISABLE_18_64	PIAAC_LIT_PCT_LEVEL2	CDCSVI_RPL_THEMES_ALL	FEA_SNAP_BENEFITS_PER_CAPITA	CDCA_PREV_DTH_BLACK_RATE_BELOW74	CHR_PCT_DIABETES	CHR_TEEN_BIRTH_RATE_15_19	SAIPE_PCT_POV	CDCP_KIDNEY_DISEASE_ADULT_A	PIAAC_NUM_PCT_LEVEL1_OR_BELOW	CHR_PCT_FOOD	SAIPE_PCT_POV_5_17	CHR_INFANT_DEATH_RATE	SAIPE_PCT_POV_0_17	CDCP_ARTHRITIS_ADULT_A	CHR_PCT_MENTAL_DISTRESS	CDCA_STROKE_HOSP_RATE_ABOVE65	CDCP_PULMONARY_ADULT_C	CDC_USCS_AGE_ADJ_MORT_RATE	CHR_PCT_SMOKING	CHR_PCT_POOR_HEALTH	CDCA_HEART_HOSP_RATE_ABOVE65	CDCSVI_RPL_THEME1_SOCIECO	CHR_PCT_PHYSICAL_DISTRESS	CDCP_BLOOD_MED_ADULT_A	CHR_PCT_PHYS_INACTIVITY	CDCP_CHOLES_ADULT_A	CDCA_STROKE_DTH_RATE_ABOVE35	CDCP_PULMONARY_ADULT_A	CDCP_NO_PHY_ACTV_ADULT_C	CDCP_NO_PHY_ACTV_ADULT_A	CHR_PREMAT_DEATH_RATE	CDCA_PREV_DTH_WHITE_RATE_BELOW74	CDCA_PREV_DTH_RATE_BELOW74	CDCA_HEART_DTH_RATE_ABOVE35	CAF_ADJ_COUNTY_14"
variables = variables.split('	')
for i in range (len(variables)):
    print(variables[i])
    print(df[variables[i]].isna().sum())
# Out:
# CAF_ADJ_COUNTY_12
# 32080
# CAF_ADJ_COUNTY_13
# 32080
# CHR_AVG_LIFE_EXPEC
# 25970
# CAF_ADJ_COUNTY_11
# 32060
# PIAAC_LIT_PCT_LEVEL3_OR_ABOVE
# 28971
# PIAAC_NUM_PCT_LEVEL3_OR_ABOVE
# 28971
# ACS_PCT_BACHELOR_DGR
# 30
# PIAAC_NUM_AVG_SCORE
# 28971
# ACS_PCT_POSTHS_ED
# 30
# SAIPE_MEDIAN_HH_INCOME
# 810
# PIAAC_LIT_AVG_SCORE
# 28971
# CHR_PCT_EXCESS_DRINK
# 19584
# SEDA_MATH_GR8_WNG
# 29900
# SEDA_CS_MN_MATH_GR8_WHT
# 12393
# SEDA_CS_MN_MATH_GR8_ALL
# 11298
# SEDA_MATH_GR3_WNG
# 29410
# SEDA_ELA_GR3_WNG
# 29454
# SEDA_ELA_GR8_WNG
# 29458
# SEDA_CS_MN_ELA_GR8_WHT
# 8410
# ACS_MEDIAN_HOME_VALUE
# 35
# SEDA_CS_MN_ELA_GR8_ALL
# 7037
# ACS_PCT_VET_BACHELOR
# 34
# ACS_PER_CAPITA_INC
# 32
# SEDA_CS_MN_MATH_GR8_MTR
# 28406
# ACS_MEDIAN_HH_INC
# 31
# ACS_PCT_HH_PC
# 25686
# ACS_MDN_OWNER_COST_MORTGAGE
# 46
# SEDA_CS_MN_MATH_GR8_NEC
# 13542
# ACS_MEDIAN_HH_INC_WHITE
# 382
# ACS_MEDIAN_NONVET_INC
# 585
# SEDA_CS_MN_ELA_GR8_MTR
# 27520
# ACS_PCT_HH_INC_100000
# 30
# ACS_PCT_HEALTH_INC_ABOVE400
# ...

# %%
wanted = "YEAR	STATE	COUNTY	COUNTYFIPS	STATEFIPS	CDCA_HEART_DTH_RATE_ABOVE35	ACS_TOT_CIVIL_POP_ABOVE18	ACS_MEDIAN_HH_INC	ACS_PCT_UNEMPLOY	ACS_PCT_OWNER_HU_COST_30PCT	ACS_PCT_HH_PUB_ASSIST	ACS_PCT_LT_HS	ACS_PCT_GRADUATE_DGR	ACS_PCT_HS_GRADUATE	ACS_PCT_POSTHS_ED	AHRF_TOT_HOSPS	AHRF_TOT_NH_BED_STNGH	AHRF_TOT_OUTPAT_VST_STNGH	AHRF_TOT_ST_G_HOSP_ADMS	AHRF_TOT_ST_G_HOSP_BED	AHRF_TOT_ST_N_G_HOSP	AHRF_TOT_STNG_LT_HOSP_ADMS"
wanted = wanted.split('	')
deleted_counties = np.array([])
cnt = 0
for name in wanted:
#     print(name)
#     print(df[df[name].isna()]['COUNTY'], end = '\n')
#     print(df[name].isna().sum())
    if (df[name].isna().sum() < 99):
        cnt+=1
        print(name + ' ' + str(df[name].isna().sum()))
        deleted_counties = np.append(deleted_counties, df[df[name].isna()]['COUNTY'])
print (cnt)
print (len(wanted))
deleted_counties = np.array(list(set(deleted_counties)))
print(deleted_counties)
print(len(deleted_counties))
# Out:
# YEAR 0
# STATE 0
# COUNTY 0
# COUNTYFIPS 0
# STATEFIPS 0
# CDCA_HEART_DTH_RATE_ABOVE35 0
# ACS_TOT_CIVIL_POP_ABOVE18 0
# ACS_MEDIAN_HH_INC 0
# ACS_PCT_UNEMPLOY 0
# ACS_PCT_OWNER_HU_COST_30PCT 0
# ACS_PCT_HH_PUB_ASSIST 0
# ACS_PCT_LT_HS 0
# ACS_PCT_GRADUATE_DGR 0
# ACS_PCT_HS_GRADUATE 0
# ACS_PCT_POSTHS_ED 0
# AHRF_TOT_HOSPS 0
# AHRF_TOT_NH_BED_STNGH 0
# AHRF_TOT_OUTPAT_VST_STNGH 0
# AHRF_TOT_ST_G_HOSP_ADMS 0
# AHRF_TOT_ST_G_HOSP_BED 0
# AHRF_TOT_ST_N_G_HOSP 0
# AHRF_TOT_STNG_LT_HOSP_ADMS 0
# 22
# 22
# []
# 0

# %%
for county in deleted_counties:
    df = df[df.COUNTY != county]

# %%
columns = np.array([])
for name in wanted:
    if (df[name].isna().sum() == 0):
        columns = np.append(columns, name)
columns
# Out:
# array(['YEAR', 'STATE', 'COUNTY', 'COUNTYFIPS', 'STATEFIPS',
#        'CDCA_HEART_DTH_RATE_ABOVE35', 'ACS_TOT_CIVIL_POP_ABOVE18',
#        'ACS_MEDIAN_HH_INC', 'ACS_PCT_UNEMPLOY',
#        'ACS_PCT_OWNER_HU_COST_30PCT', 'ACS_PCT_HH_PUB_ASSIST',
#        'ACS_PCT_LT_HS', 'ACS_PCT_GRADUATE_DGR', 'ACS_PCT_HS_GRADUATE',
#        'ACS_PCT_POSTHS_ED', 'AHRF_TOT_HOSPS', 'AHRF_TOT_NH_BED_STNGH',
#        'AHRF_TOT_OUTPAT_VST_STNGH', 'AHRF_TOT_ST_G_HOSP_ADMS',
#        'AHRF_TOT_ST_G_HOSP_BED', 'AHRF_TOT_ST_N_G_HOSP',
#        'AHRF_TOT_STNG_LT_HOSP_ADMS'], dtype='<U32')

# %%
filtered_df = df[columns].copy()

# %%
for column in filtered_df.columns:
    print (column)
#     if "TOT" in column:
#         print (column)
# Out:
# YEAR
# STATE
# COUNTY
# COUNTYFIPS
# STATEFIPS
# CDCA_HEART_DTH_RATE_ABOVE35
# ACS_TOT_CIVIL_POP_ABOVE18
# ACS_MEDIAN_HH_INC
# ACS_PCT_UNEMPLOY
# ACS_PCT_OWNER_HU_COST_30PCT
# ACS_PCT_HH_PUB_ASSIST
# ACS_PCT_LT_HS
# ACS_PCT_GRADUATE_DGR
# ACS_PCT_HS_GRADUATE
# ACS_PCT_POSTHS_ED
# AHRF_TOT_HOSPS
# AHRF_TOT_NH_BED_STNGH
# AHRF_TOT_OUTPAT_VST_STNGH
# AHRF_TOT_ST_G_HOSP_ADMS
# AHRF_TOT_ST_G_HOSP_BED
# AHRF_TOT_ST_N_G_HOSP
# AHRF_TOT_STNG_LT_HOSP_ADMS

# %%
filtered_df
# Out:
#        YEAR    STATE             COUNTY  COUNTYFIPS  STATEFIPS  \
# 0      2009  Alabama     Autauga County        1001          1
# 1      2009  Alabama     Baldwin County        1003          1
# 2      2009  Alabama     Barbour County        1005          1
# 3      2009  Alabama        Bibb County        1007          1
# 4      2009  Alabama      Blount County        1009          1
# ...     ...      ...                ...         ...        ...
# 32014  2019  Wyoming  Sweetwater County       56037         56
# 32015  2019  Wyoming       Teton County       56039         56
# 32016  2019  Wyoming       Uinta County       56041         56
# 32017  2019  Wyoming    Washakie County       56043         56
# 32018  2019  Wyoming      Weston County       56045         56
#
#        CDCA_HEART_DTH_RATE_ABOVE35  ACS_TOT_CIVIL_POP_ABOVE18  \
# 0                            631.3                    35000.0
# 1                            531.8                   131616.0
# ...

# %%
for column in filtered_df.columns:
    if "TOT" in column and column not in ["ACS_TOT_CIVIL_POP_ABOVE18"]:
        filtered_df[column] = filtered_df.apply(lambda x: x[column]/x['ACS_TOT_CIVIL_POP_ABOVE18'] * 100000, axis=1)

# %%
filtered_df
# Out:
#        YEAR    STATE             COUNTY  COUNTYFIPS  STATEFIPS  \
# 0      2009  Alabama     Autauga County        1001          1
# 1      2009  Alabama     Baldwin County        1003          1
# 2      2009  Alabama     Barbour County        1005          1
# 3      2009  Alabama        Bibb County        1007          1
# 4      2009  Alabama      Blount County        1009          1
# ...     ...      ...                ...         ...        ...
# 32014  2019  Wyoming  Sweetwater County       56037         56
# 32015  2019  Wyoming       Teton County       56039         56
# 32016  2019  Wyoming       Uinta County       56041         56
# 32017  2019  Wyoming    Washakie County       56043         56
# 32018  2019  Wyoming      Weston County       56045         56
#
#        CDCA_HEART_DTH_RATE_ABOVE35  ACS_TOT_CIVIL_POP_ABOVE18  \
# 0                            631.3                    35000.0
# 1                            531.8                   131616.0
# ...

# %%
filtered_df.to_csv('SDOH_Filtered_Data_Per_Capita.csv', index = False)
